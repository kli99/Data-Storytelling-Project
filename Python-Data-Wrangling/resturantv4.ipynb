# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import csv
from bs4 import BeautifulSoup
import string
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt
from collections import Counter

# %%
from flask import Flask, render_template, redirect
import json

# %%
import seaborn as sns

# %%
NYC_restaurant_csv = "assets/data/NYCRestaurant_Inspection.csv"
NYC_restaurant_df = pd.read_csv(NYC_restaurant_csv,encoding="utf8")

# %%
NYC_restaurant_df.groupby(['CUISINE DESCRIPTION', 'ZIPCODE'], as_index=True)['SCORE'].mean()
# Out:
# CUISINE DESCRIPTION            ZIPCODE
# Afghan                         10003.0    24.242424
#                                10018.0    10.000000
#                                10019.0    10.071429
#                                10021.0     7.400000
#                                11004.0    11.090909
#                                             ...
# Vietnamese/Cambodian/Malaysia  11355.0    18.311475
#                                11358.0    28.703704
#                                11361.0    13.833333
#                                11362.0    15.545455
#                                11373.0    16.078947
# Name: SCORE, Length: 5040, dtype: float64

# %%
# Average score by zipcode
zipcode_df=NYC_restaurant_df.groupby('ZIPCODE', as_index=True)['SCORE'].mean()
zipcode_df
# Out:
# ZIPCODE
# 10000.0    14.000000
# 10001.0    19.799711
# 10002.0    22.504798
# 10003.0    20.320081
# 10004.0    18.943284
#              ...
# 11693.0    18.405896
# 11694.0    17.793503
# 11697.0    13.923077
# 12345.0    11.222222
# 30339.0    13.142857
# Name: SCORE, Length: 227, dtype: float64

# %%
# Average score by cusine 
cuisine_df=NYC_restaurant_df.groupby("CUISINE DESCRIPTION", as_index=True)['SCORE'].mean()
cuisine_df
# Out:
# CUISINE DESCRIPTION
# Afghan                           18.813397
# African                          27.762606
# American                         18.917432
# Armenian                         18.618243
# Asian                            21.876633
#                                    ...
# Tex-Mex                          18.048071
# Thai                             21.695994
# Turkish                          21.414378
# Vegetarian                       21.380464
# Vietnamese/Cambodian/Malaysia    22.464396
# Name: SCORE, Length: 84, dtype: float64

# %%
cuisine_df.plot.bar()

# %%
# Average score by cusine 
cuisine_df=NYC_restaurant_df.groupby("CUISINE DESCRIPTION", as_index=True)['SCORE'].mean()
cuisine_df
plt.show()

# %%
cuisine_df.plot.scatter
