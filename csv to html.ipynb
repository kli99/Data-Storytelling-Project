# %%
import pandas as pd

# %%
file = "data/dataset.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#       CAMIS                     DBA       BORO BUILDING            STREET  \
# 0  50045803  PUNJABI KABAB AND GYRO     Queens    10803         101ST AVE
# 1  50060589   EL MARIACHI RESTAURNT     Queens     6712     ROOSEVELT AVE
# 2  41682808             JOSIE'S BAR  Manhattan      520  EAST    6 STREET
# 3  40483697   LUNT FONTANNE THEATER  Manhattan      205  WEST   46 STREET
# 4  50059948               ESTAMINET   Brooklyn     107A          7 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0    11416  7187099919              Indian        2/2/2019
# 1    11377  7183356744             Mexican      11/16/2018
# 2    10009  2122289532            American        2/7/2018
# 3    10036  2123544624            American        5/3/2017
# 4    11215  9174994191     Café/Coffee/Tea        3/6/2019
#
#                                             ACTION  ... RECORD DATE  \
# 0  Violations were cited in the following area(s).  ...   9/10/2020
# 1  Violations were cited in the following area(s).  ...   9/10/2020
# 2  Violations were cited in the following area(s).  ...   9/10/2020
# 3  Violations were cited in the following area(s).  ...   9/10/2020
# 4  Violations were cited in the following area(s).  ...   9/10/2020
#
#                          INSPECTION TYPE   Latitude  Longitude  \
# 0       Cycle Inspection / Re-inspection  40.687314 -73.835288
# 1       Cycle Inspection / Re-inspection  40.746152 -73.897899
# 2  Cycle Inspection / Initial Inspection  40.725172 -73.983285
# 3  Cycle Inspection / Initial Inspection  40.758891 -73.985796
# 4  Cycle Inspection / Initial Inspection  40.673914 -73.975814
#
#   Community Board Council District Census Tract      BIN         BBL   NTA
# 0             409               28        11000  4197917  4094100035  QN54
# 1             402               26        26300  4000000  4012990027  QN63
# 2             103                2         3200  1005052  1004010020  MN22
# 3             105                3        12500  1024739  1010180020  MN17
# 4             306               39        15700  3024679  3010650069  BK37
#
# [5 rows x 26 columns]

# %%
df.to_html(classes = "table table-bordered table-striped", index=False)
